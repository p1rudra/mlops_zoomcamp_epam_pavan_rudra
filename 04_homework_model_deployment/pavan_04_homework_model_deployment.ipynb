# %% [markdown]
# # Pavan's Homework

# %% [markdown]
# #04_homework_model_deployment

# %% [markdown]
# ## Q1. Run this notebook for the March 2023 data. What's the standard deviation of the predicted duration for this dataset?
# 1.24
#
# 6.24
#
# 12.28
#
# 18.28
#
# ## Pavan's Answer : 6.24
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q2. What's the size of the output file?
#
# 36M
#
# 46M
#
# 56M
#
# 66M
#
# Vishal's Answer : 66 M
#
# ![image.png](attachment:50adec09-cc62-4f15-b36b-bf6c3311f4ca.png)

# %% [markdown]
# ## Q3. Creating the scoring script
# Now let's turn the notebook into a script.
#
# Which command you need to execute for that?
#
# ## Pavan's Answer: jupyter nbconvert --to script
# homework_Q3_scoring_notebook.ipynb
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q4. Virtual environment
# Now let's put everything into a virtual environment. We'll use pipenv for that.
#
# Install all the required libraries. Pay attention to the Scikit-Learn version: it should be the same as in the starter notebook.
#
# After installing the libraries, pipenv creates two files: Pipfile and Pipfile.lock. The Pipfile.lock file keeps the hashes of the dependencies we use for the virtual env.
#
# What's the first hash for the Scikit-Learn dependency?
#
# ## Pavan's Answer (please find the screenshot related to this answer below): --hash=sha256:ceebae7b8927a3227e5303cf5e0f1f7b34bb542ad7250ac03fbcde36ec2f1508

# %% [markdown]
# ## Pavan's Answer related screenshots for Q4 : --hash=sha256:ceebae7b8927a3227e5303cf5e0f1f7b34bb542ad7250ac03fbcde36ec2f1508
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Q5. Parametrize the script
# Let's now make the script configurable via CLI. We'll create two parameters: year and month.
#
# Run the script for April 2023.
#
# What's the mean predicted duration?
#
# 7.29
#
# 14.29
#
# 21.29
#
# 28.29
#
# Hint: just add a print statement to your script.
#
# ## Pavan's Answer : 14.29
#
# --> Creating Parametrize script (please find homework_q5_answer_parametrize_script.py)
#
# ![image.png](attachment:image.png)
#
#
# -> developed  the code in notebook
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Q6. Docker container
# Now run the script with docker. What's the mean predicted duration for May 2023?
#
# 0.19
#
# 7.24
#
# 14.24
#
# 21.19
#
# ## Pavan's Answer : 0.19
#
#
# ![image.png](attachment:image.png)

# %%
import pickle
import pandas as pd
import sklearn

# %%
sklearn.__version__
# Out:
# '1.5.0'

# %%
year = 2023
month = 3

input_file = f'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year:04d}-{month:02d}.parquet'
output_file = f'output/yellow_tripdata_{year:04d}-{month:02d}.parquet'

# %%
year = 2023
month = 3

input_file = f'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year:04d}-{month:02d}.parquet'
output_file = f'output/yellow_tripdata_{year:04d}-{month:02d}.parquet'

# %%
# !mkdir output
# Out:
# mkdir: cannot create directory ‘output’: File exists

# %%
with open('model.bin', 'rb') as f_in:
    dv, lr = pickle.load(f_in)

# %%
categorical = ['PULocationID', 'DOLocationID']

def read_data(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df['duration'] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
    
    return df

# %%
df = read_data(input_file)
df['ride_id'] = f'{year:04d}/{month:02d}_' + df.index.astype('str')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-03-01 00:06:43   2023-03-01 00:16:43              1.0
# 1         2  2023-03-01 00:08:25   2023-03-01 00:39:30              2.0
# 2         1  2023-03-01 00:15:04   2023-03-01 00:29:26              0.0
# 3         1  2023-03-01 00:49:37   2023-03-01 01:01:05              1.0
# 4         2  2023-03-01 00:08:04   2023-03-01 00:11:06              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag PULocationID DOLocationID  \
# 0           0.00         1.0                  N          238           42
# 1          12.40         1.0                  N          138          231
# 2           3.30         1.0                  N          140          186
# 3           2.90         1.0                  N          140           43
# 4           1.23         1.0                  N           79          137
#
#    payment_type  ...  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
dicts = df[categorical].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = lr.predict(X_val)

# %%
y_pred
# Out:
# array([16.24590642, 26.1347962 , 11.88426424, ..., 11.59533603,
#        13.11317847, 12.89999218])
